# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import chardet
import openpyxl

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/4.3 Customer Booking Data.csv')

# %%
df
# Out:
#        num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0                   2      Internet  RoundTrip            262              19
# 1                   1      Internet  RoundTrip            112              20
# 2                   2      Internet  RoundTrip            243              22
# 3                   1      Internet  RoundTrip             96              31
# 4                   2      Internet  RoundTrip             68              22
# ...               ...           ...        ...            ...             ...
# 49995               2      Internet  RoundTrip             27               6
# 49996               1      Internet  RoundTrip            111               6
# 49997               1      Internet  RoundTrip             24               6
# 49998               1      Internet  RoundTrip             15               6
# 49999               1      Internet  RoundTrip             19               6
#
# ...

# %%
df.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2      Internet  RoundTrip            262              19
# 1               1      Internet  RoundTrip            112              20
# 2               2      Internet  RoundTrip            243              22
# 3               1      Internet  RoundTrip             96              31
# 4               2      Internet  RoundTrip             68              22
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            7        Sat  AKLDEL    New Zealand                    1
# 1            3        Sat  AKLDEL    New Zealand                    0
# 2           17        Wed  AKLDEL          India                    1
# 3            4        Sat  AKLDEL    New Zealand                    0
# 4           15        Wed  AKLDEL          India                    1
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_passengers         50000 non-null  int64
#  1   sales_channel          50000 non-null  object
#  2   trip_type              50000 non-null  object
#  3   purchase_lead          50000 non-null  int64
#  4   length_of_stay         50000 non-null  int64
#  5   flight_hour            50000 non-null  int64
#  6   flight_day             50000 non-null  object
#  7   route                  50000 non-null  object
#  8   booking_origin         50000 non-null  object
#  9   wants_extra_baggage    50000 non-null  int64
#  10  wants_preferred_seat   50000 non-null  int64
#  11  wants_in_flight_meals  50000 non-null  int64
#  12  flight_duration        50000 non-null  float64
#  13  booking_complete       50000 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
df['flight_day'].unique()
# Out:
# array(['Sat', 'Wed', 'Thu', 'Mon', 'Sun', 'Tue', 'Fri'], dtype=object)

# %%
mapping = {
    "Mon": 1,
    "Tue": 2,
    "Wed": 3,
    "Thu": 4,
    "Fri": 5,
    "Sat": 6,
    "Sun": 7,
}

df["flight_day"] = df["flight_day"].map(mapping)

# %%
df["flight_day"].unique()
# Out:
# array([6, 3, 4, 1, 7, 2, 5])

# %%
df.describe()
# Out:
#        num_passengers  purchase_lead  length_of_stay  flight_hour  \
# count    50000.000000   50000.000000     50000.00000  50000.00000
# mean         1.591240      84.940480        23.04456      9.06634
# std          1.020165      90.451378        33.88767      5.41266
# min          1.000000       0.000000         0.00000      0.00000
# 25%          1.000000      21.000000         5.00000      5.00000
# 50%          1.000000      51.000000        17.00000      9.00000
# 75%          2.000000     115.000000        28.00000     13.00000
# max          9.000000     867.000000       778.00000     23.00000
#
#          flight_day  wants_extra_baggage  wants_preferred_seat  \
# count  50000.000000         50000.000000          50000.000000
# mean       3.814420             0.668780              0.296960
# std        1.992792             0.470657              0.456923
# min        1.000000             0.000000              0.000000
# ...

# %%
df.shape
# Out:
# (50000, 14)

# %%
X= df.drop('booking_complete',axis=1)
y= df.booking_complete

#changing object dtype to int dtype
for colname in X.select_dtypes("object"):
    X[colname], _ = X[colname].factorize()

# %%
X
# Out:
#        num_passengers  sales_channel  trip_type  purchase_lead  \
# 0                   2              0          0            262
# 1                   1              0          0            112
# 2                   2              0          0            243
# 3                   1              0          0             96
# 4                   2              0          0             68
# ...               ...            ...        ...            ...
# 49995               2              0          0             27
# 49996               1              0          0            111
# 49997               1              0          0             24
# 49998               1              0          0             15
# 49999               1              0          0             19
#
#        length_of_stay  flight_hour  flight_day  route  booking_origin  \
# 0                  19            7           6      0               0
# ...

# %%
X.dtypes
# Out:
# num_passengers             int64
# sales_channel              int64
# trip_type                  int64
# purchase_lead              int64
# length_of_stay             int64
# flight_hour                int64
# flight_day                 int64
# route                      int64
# booking_origin             int64
# wants_extra_baggage        int64
# wants_preferred_seat       int64
# wants_in_flight_meals      int64
# flight_duration          float64
# dtype: object

# %%
from sklearn.feature_selection import mutual_info_classif

mi_scores = mutual_info_classif(X, y)
mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
mi_scores = mi_scores.sort_values(ascending=False)

mi_scores
# Out:
# route                    0.053738
# booking_origin           0.046542
# flight_duration          0.014709
# length_of_stay           0.008816
# wants_extra_baggage      0.007342
# wants_preferred_seat     0.003433
# wants_in_flight_meals    0.002708
# flight_day               0.001127
# num_passengers           0.000960
# sales_channel            0.000618
# purchase_lead            0.000549
# flight_hour              0.000346
# trip_type                0.000000
# Name: MI Scores, dtype: float64

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores")


plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores)

# %%
# prompt: provide me a pie chart for above one and provide every column name

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 60))
plt.pie(mi_scores, labels=mi_scores.index, autopct='%1.1f%%')
plt.title("Mutual Information Scores")
plt.show()

# %%
from sklearn.model_selection import train_test_split

def dataset(X,y):
    train_full_X, val_X, train_full_y, val_y = train_test_split(X, y, test_size = 0.2, random_state =0)

    train_X, test_X, train_y, val_y = train_test_split(train_full_X, train_full_y, test_size = 0.25, random_state = 0)
    return(train_X, val_X, train_y, val_y)

# %%
# prompt: give me a pie chart for it

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))
plt.pie(mi_scores, labels=mi_scores.index, autopct='%1.1f%%')
plt.title("Mutual Information Scores")
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

def scale(X):
    scaler = MinMaxScaler()
    scaler.fit(X)
    return X

# %% [markdown]
# # Random Forest

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

features = ['route', 'booking_origin', 'flight_duration','wants_extra_baggage', 'length_of_stay', 'num_passengers' ]
X = df[features]

X = pd.get_dummies(X, columns=features)
X = scale(X)
y = df.booking_complete

X_train, X_val, y_train, y_val = dataset(X,y)

forest_model = RandomForestClassifier(random_state=1)
forest_model.fit(X_train, y_train)
preds = forest_model.predict(X_val)

print('ACCURACY: ', accuracy_score(y_val, preds)*100)
print('AUC SCORE: ', roc_auc_score(y_val, preds))
# Out:
# ACCURACY:  80.08
# AUC SCORE:  0.5015899814756185

# %%
X= df.drop('booking_complete',axis=1)
#one hot encoding
X = pd.get_dummies(X)
X= scale(X)
y= df.booking_complete

X_train,X_val,y_train,y_val= dataset(X,y)

forest_model= RandomForestClassifier(random_state=1)
forest_model.fit(X_train, y_train)
preds= forest_model.predict(X_val)

print('ACCURACY: ',accuracy_score(y_val,preds)*100)
print('AUC score: ',roc_auc_score(y_val,preds))
# Out:
# ACCURACY:  82.16
# AUC score:  0.5002407834360953

# %%
# prompt: give the workflow for above one to write in ppt

**Slide 1: Title Slide**

* Title: Customer Booking Data Analysis
* Subtitle: Using Machine Learning to Predict Booking Completion
* Presenter: [Your Name]

**Slide 2: Introduction**

* Overview of the project:
    * Predicting whether a customer will complete their booking based on various factors
* Importance of the problem:
    * Helps airlines optimize revenue and improve customer satisfaction

**Slide 3: Data Exploration**

* Data source:
    * Customer booking data from Google Drive
* Data cleaning:
    * Handling missing values
    * Converting categorical variables to numerical values
* Exploratory data analysis:
    * Understanding the distribution of variables
    * Identifying potential relationships between variables

**Slide 4: Feature Selection**

* Mutual information:
    * Used to measure the relationship between variables
* Feature selection using mutual information:
    * Identifying the most informative features for predicting booking completion

**Slide 5: Model Building**

* Random Forest Classifier:
    * Ensemble learning algorithm that combines multiple decision trees
* Model training:
    * Splitting the data into training and validation sets
    * Training the Random Forest model on the training set

**Slide 6: Model Evaluation**

* Accuracy:
    * Percentage of correctly predicted bookings
* AUC score:
    * Measures the model's ability to distinguish between positive and negative cases

**Slide 7: Results**

* Accuracy of the model:
    * [Accuracy score]
* AUC score of the model:
    * [AUC score]

**Slide 8: Conclusion**

* Summary of the findings:
    * The Random Forest model can accurately predict booking completion
* Potential applications of the model:
    * Optimizing airline revenue
    * Improving customer satisfaction

**Slide 9: Future Work**

* Possible extensions of the project:
    * Exploring other machine learning algorithms
    * Incorporating additional data sources
    * Developing a real-time prediction system

**Slide 10: Questions and Discussion**

* Open the floor for questions and discussion from the audience

# %%
# prompt: provide me workflow in single slide providing boxes for this project like firstbox has customer bookings and nxt box has..randomforest model like this

**Slide Title: Customer Booking Data Analysis Workflow**

**Box 1: Data Collection**

* Collect customer booking data from Google Drive

**Box 2: Data Preprocessing**

* Handle missing values
* Convert categorical variables to numerical values

**Box 3: Exploratory Data Analysis**

* Understand the distribution of variables
* Identify potential relationships between variables

**Box 4: Feature Selection**

* Use mutual information to identify the most informative features

**Box 5: Model Training**

* Split the data into training and validation sets
* Train the Random Forest model on the training set

**Box 6: Model Evaluation**

* Evaluate the model's accuracy and AUC score

**Box 7: Conclusion**

* The Random Forest model can accurately predict booking completion

**Box 8: Future Work**

* Explore other machine learning algorithms
* Incorporate additional data sources
* Develop a real-time prediction system
